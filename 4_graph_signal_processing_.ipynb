# %% [markdown]
# # [NTDS'18] milestone 4: graph signal processing
# [ntds'18]: https://github.com/mdeff/ntds_2018
#
# [Rodrigo Pena](https://people.epfl.ch/254838), [EPFL LTS2](http://lts2.epfl.ch)

# %% [markdown]
# ## Students
#
# * Team: `12`
# * Students: `Arnaud Duvieusart, Omar Boujdaria, Franck Dessimoz and Adrien Vandenbroucque`
# * Dataset: `Flight Routes`

# %% [markdown]
# ## Rules
#
# * Milestones have to be completed by teams. No collaboration between teams is allowed.
# * Textual answers shall be short. Typically one to two sentences.
# * Code has to be clean.
# * You cannot import any other library than we imported.
# * When submitting, the notebook is executed and the results are stored. I.e., if you open the notebook again it should show numerical results and plots. We won't be able to execute your notebooks.
# * The notebook is re-executed from a blank state before submission. That is to be sure it is reproducible. You can click "Kernel" then "Restart & Run All" in Jupyter.

# %% [markdown]
# ## Objective
#
# The goal of this milestone is to do some Graph Signal Processing (GSP) on the data of your project.
#
# ### A note about plotting
#
# There are several questions in this milestone that ask you to plot a signal on your network.
# There are several ways from which you could approach it.
# In all cases, compute the position of the nodes a single time at the beginning, as this is likely to be a costly operation.
# Using a single layout for all the graph plots will also make it easier to compare the plots.
# Indeed, the only thing changing between plots is the signal displayed.
# You can represent the features/labels lying on the graph via node **colors**.
# To do so, make sure to have a consistent color map throughout and remember to display a colorbar and scale in all plots, so that we can tell what numbers the colors represent.
#
# * An option is to use the **Laplacian eigenmaps** that you have seen in the previous milestone to embed your graph on the plane. For example:
#   ```
#   from matplotlib import pyplot as plt
#   plt.scatter(eigenvectors[:, 1], eigenvectors[:, 2], c=signal, alpha=0.5)
#   plt.colorbar()
#   ```
# * Another option is to use the plotting capabilities of **[NetworkX](https://networkx.github.io)**.
#   See the documentation of its [drawing methods](https://networkx.github.io/documentation/stable/reference/drawing.html).
#   For example:
#   ```
#   import networkx as nx
#   graph = nx.from_scipy_sparse_matrix(adjacency)
#   coords = nx.spring_layout(graph)  # Force-directed layout.
#   coords = eigenvectors[:, 1:3]  # Laplacian eigenmaps.
#   nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=signal)
#   nx.draw_networkx_edges(graph, coords, alpha=0.3)
#   ```
# * Another option is to use the plotting capabilities of the **[PyGSP](https://github.com/epfl-lts2/pygsp)**, a Python package for Graph Signal Processing.
#   **Note that your are forbidden to use the PyGSP for anything else than plotting.**
#   See the documentation of its [plotting utilities](https://pygsp.readthedocs.io/en/stable/reference/plotting.html).
#   For example:
#   ```
#   import pygsp as pg
#   graph = pg.graphs.Graph(adjacency)
#   graph.set_coordinates('spring')  # Force-directed layout.
#   graph.set_coordinates(eigenvectors[:, 1:3])  # Laplacian eigenmaps.
#   graph.plot_signal(signal)
#   ```
# * Yet another option is to save your graph on disk, use **[Gephi](https://gephi.org)** externally, to visualize the graph, save the graph with the Gephi coordinates and finally load the nodes coordinates back into the notebook.
#
# We encourage you to try all the above methods before making your choice. Then be consistent and use only one throughout the milestone.
# NetworkX and PyGSP should already be installed in your environement. If that's not the case, install with `conda install networkx pygsp` (after activating the `ntds_2018` environment).

# %% [markdown]
# ## 0 - Load your network

# %%
# %matplotlib inline

# %% [markdown]
# If you get a `No module named 'pyunlocbox'` error when running the below cell, install the [pyunlocbox](https://github.com/epfl-lts2/pyunlocbox) with `conda install pyunlocbox` (after activating the `ntds_2018` environment).

# %%
import numpy as np
import pandas as pd
import networkx as nx
from scipy import sparse
import scipy.sparse.linalg
from matplotlib import pyplot as plt
from pyunlocbox import functions, solvers
import seaborn as sns

# %% [markdown]
# For this milestone, all we will need is a set of features/labels for each of the nodes on the network, as well as the Laplacian, $L,$ and Gradient, $\nabla_G,$ matrices that you have computed for your network while working on milestone 3.
#
# Import those objects in the cell below (or recompute the Laplacian and Gradient from your stored adjacency matrix, if you wish).
#
# _Note_: If your features/labels are not floating-point numbers, please convert them. For example, if your data has labels "cat" and "dog" for nodes that represent cats or dogs, respectively, you may assign the number `1.0` for the label "cat" and the number `-1.0` for the label "dog".

# %%
#Load the adjacency matrix from previous milestone
adjacency =  np.load('adj.npy')
graph = nx.from_numpy_matrix(adjacency)
laplacian = nx.laplacian_matrix(graph)
gradient = nx.incidence_matrix(graph, oriented=True).T
labels = np.load('labels.npy')
n_nodes = len(adjacency)

# %% [markdown]
# ## 1 - Graph Fourier Transform
#
# In this section we will observe how your feature/label vector looks like in the "Graph Fourier" domain.

# %% [markdown]
# ### Question 1
#
# Compute the Fourier basis vectors and the Laplacian eigenvalues. Make sure to order those from smaller to larger, $\lambda_0 \leq \lambda_1 \leq \dots \leq \lambda_{N-1},$ and use the same ordering for the Fourier basis vectors.

# %%
e, U =  scipy.linalg.eigh(laplacian.toarray())

# %% [markdown]
# Plot the first 3 and the last Fourier basis vectors as signals on your graph. Clearly indicate which plot belongs to which basis vector.

# %%
# Indice of the first non-zero eigenvalue
lambda_1_ind = 7

# Laplacian eigenmaps
coords = U[:, lambda_1_ind:lambda_1_ind+2]

def plot_signal(signal):
    nodes = nx.draw_networkx_nodes(graph, coords, node_size=60, node_color=signal)
    plt.xlabel('Value of $\lambda_7$')
    plt.ylabel('Value of $\lambda_8$')
    plt.colorbar(nodes)

# %%
plt.figure(figsize=(20, 20))

# Plot the first 3 Fourier basis vectors
for i in range(3):
    plt.subplot(321 + 2*i)
    plot_signal(U[:, lambda_1_ind + i])
    plt.title('Plot for the signal being $u_{'+ str(lambda_1_ind + i)+'}$')

    # Plot the last 3 Fourier basis vectors
for i in range(3):
    plt.subplot(322 + 2*i)
    plot_signal(U[:, n_nodes - (i + 1)])
    plt.title('Plot for the signal being $u_{'+ str(n_nodes - (i + 1))+'}$')

plt.show()

# %% [markdown]
# ### Question 2
#
# What can you observe in terms of local variations when comparing the basis vectors corresponding to the smallest eigenvalues to those corresponding to the largest eigenvalue? How would this justify the interpretation of the eigenvalues as "graph frequencies"?

# %% [markdown]
# ***We can see that for the first three non-zero eigenvalues, plotting their corresponding eigenvectors as signals show various components of our graph. For example, for the first one, the nodes on one of the axis have different values from those on the other one, which all have value around $0$. For the second eigenvector, the same happens but on the other axis. And finally, for the third one, some nodes at the intersection of the axes formed by the nodes have different values, and all the rest have value $0$.***
#
# ***For the last 3 eigenvectors, we see that all nodes have value zero, or very close to zero. So it seems that when we go in the last eigenvectors, all nodes are part of a same kind of cluster.***

# %% [markdown]
# ### Question 3
#
# Implement a function that returns the Graph Fourier Transform (GFT) of a given vector $x \in \mathbb{R}^{N},$ with respect to your graph, and a function that computes the corresponding inverse GFT (iGFT).

# %%
def GFT(x):
    return np.matmul(np.transpose(U), x)

def iGFT(x):
    return np.matmul(U, x)

# %% [markdown]
# ### Question 4
#
# Plot your feature/label vector as a signal on your graph

# %%
plot_signal(labels)
plt.title('Plot for the signal being $u_{'+ str(lambda_1_ind + i)+'}$')
plt.show()

# %% [markdown]
# Plot the absolute values of the GFT of your feature/label signal as a function of the graph eigenvalues. Make sure to add a marker indicating the position of each graph eigenvalue, and remember to properly name the axes.

# %%
def plot_spectral(signal):
    plt.plot(e, signal)
    plt.xlabel('Eigenvalues')
    plt.ylabel('Value of the signal')

# %%
# Compute the GFT of labels and take absolute value
abs_gft = np.abs(GFT(labels))

# Plot the signal as a function of the eigenvalues
plot_spectral(abs_gft)
plt.title('Absolute value of the GFT of the labels signal as a function of the eigenvalues')

plt.show()

# %% [markdown]
# ### Question 5
#
# Discuss the behavior of the GFT that you plotted in the last question via comparing the plot of your label signal and those of the Fourier basis of Question 1. Would you consider your labels a "low-pass" or "high-pass" signal, or yet something else entirely?

# %% [markdown]
# **Similarly to Question 1  basis, we can observe the high peak at 0, followed by relatively low values along the X-axis. As thisis GFT graph, we can consider that our labels are low pass since the only high value appear at 0.**

# %% [markdown]
# ## 2 - Filtering on graphs
#
# In this section we will check how filtered Dirac impulses diffuse on your graph.

# %% [markdown]
# ### Question 6
#
# Implement the following three filter kernels and the graph filtering operation.
#
# - The **heat kernel** is supposed to take in a vector of eigenvalues `e` and a parameter `t` and output a vector of evaluations of the heat kernel at those eigenvalues (see the course slides for help).
# - The **inverse filter** kernel is supposed to take in a vector of eigenvalues `e` and a parameter `t` and implement spectrally the  filter defined in the node domain by $f_{out}  = (I + t L)^{-1} f_{in},$ where $f_{in}, f_{out} \in \mathbb{R}^{N}$ are, repectively, the input and output signals to the filter.
# - The **rectangle kernel** takes in a vector of eigenvalues `e` and parameters `l_min` and `l_max` and returns `1.0` at coordinates satisfying $(e[l] \geq l_{min}) \wedge (e[l] \leq l_{max}),$ and `0.0` otherwise.
# - The **graph filtering** operation takes a graph signal $x \in \mathbb{R}^{N}$, a spectral graph `kernel` and a set of keyworded variables, and returns the corresponding filtered signal.
#     - _Hint:_ Remember that you have implemented the `GFT` and `iGFT` operations in Question 3.
#     - The `**kwargs` is a placeholder to collect supplementary pairs of keyword-values that are not known by the implementation before execution time.
#       The `kwargs` variable is a dictionary whose keyes and values are the parameter names and values.
#       This is useful to allow both `graph_filter(x, heat_kernel, tau=1.0)` and `graph_filter(x, rectangle_kernel, lambda_min=0.0, lambda_max=1.0)` to be valid calls from the same implementation.
#       One can then defer the keyword-value assignment to the `kernel` call: `foo = kernel(bar, **kwargs)`.

# %%
def heat_kernel(e, t):
    return np.exp(-t * e)

def inverse_kernel(e, t):
    inv = np.dot(np.linalg.inv(np.identity(n_nodes) + t * laplacian), e).T
    return inv

def rectangle_kernel(e, l_min, l_max):
    return np.bitwise_and(e <= l_max, e >= l_min).astype(float)

def graph_filter(x, kernel, **kwargs):
    # Go to Fourier domain
    x = GFT(x)
    print('Shape after GFT', x.shape)
    
    # Apply the kernel
    k = kernel(**kwargs)
    x = x.reshape(k.shape) # TODO LOOK WHY DOESNT WORK
    x = np.multiply(x, k)
    
    print('Shape after kernel', x.shape)
    #Perform inverse Fourier transform
    return iGFT(x)

# %% [markdown]
# ### Question 7
#
# Plot all three filter kernels in the spectral domain. Remember to properly name the axes and title the plots. Choose filter parameters that best approximate the behavior of the GFT of your feature/label signal (as seen in Question 4).

# %%
plt.figure(figsize=(20, 5))

plt.subplot(131)
plot_spectral(heat_kernel(e, 0.5))
plt.title('Heat kernel as a function of the eigenvalues')

plt.subplot(132)
plot_spectral(inverse_kernel(e, -0.1))
plt.title('Inverse kernel as a function of the eigenvalues')

plt.subplot(133)
plot_spectral(rectangle_kernel(e, 0, 5))
plt.title('Rectangle kernel as a function of the eigenvalues')

plt.show()

# %% [markdown]
# ### Question 8
#
# Consider two Dirac impulses arbitrarily placed on your graph. Plot their filtered versions by the three filter kernels implemented in Question 6.

# %%
dirac_ind = np.random.randint(n_nodes, size=2)
dirac_pulses = np.zeros(n_nodes)
dirac_pulses[dirac_ind] = 10


filtered_heat = graph_filter(dirac_pulses, heat_kernel, e=e, t=0.5)
#filtered_inv = graph_filter(dirac_pulses, inverse_kernel, e=e, t=t)
filtered_rec = graph_filter(dirac_pulses, rectangle_kernel, e=e, l_min=0, l_max=5)

plt.figure(figsize=(20, 5))
plt.subplot(131)
plot_signal(filtered_heat)
plt.title('Plot of the filtered signal on the graph with heat kernel')

"""plot_signal(filtered_inv)
plt.title('Plot of the filtered signal on the graph with inverse kernel')"""

plt.subplot(133)
plot_signal(filtered_rec)
plt.title('Plot of the filtered signal on the graph with rectangle kernel')

plt.show()
# Out:
# Shape after GFT (3330,)
# Shape after kernel (3330,)
# Shape after GFT (3330,)
# Shape after kernel (3330,)

# %% [markdown]
# Comment on the "diffusion" of the Diracs induced by the filters. What does it say about the "communication" of information across your network? Relate that to the network connectivity measures that you analyzed during the previous milestones.

# %% [markdown]
# **Your answer here.**

# %% [markdown]
# ## 3 - De-noising
#
# In this section we will add some centered Gaussian noise to your feature/label signal and attempt to recover it.

# %% [markdown]
# ### Question 9
#
# In the cell below, set the noise variance $\sigma^2$ by making sure that the signal-to-noise ratio $SNR = \frac{\operatorname{Var}(\text{labels})}{\sigma^2}$ is about  $1.5$.
#
# _Note:_ Actually, you might want to play with the noise variance here and set it to different values and see how the denoising filters behave.

# %%
SNR = 1.5
noise_variance = np.var(labels) / SNR
noisy_measurements = labels + noise_variance * np.random.randn(n_nodes)

# %% [markdown]
# ### Question 10
#
# In the denoising setting, a common graph signal processing assumption is that the signal $z$ that we want to recover is "smooth", in the sense that $\|\nabla_G z\|_2 = \sqrt{z^{\top} L z}$ is small, while remaining "close" to the measurements that we start with. This leads to denoising by solving the following optimization problem:
#
# $$
# z^\star = \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \, \|z - y\|_2^2 + \gamma z^{\top} L z,
# $$
#
# where $y \in \mathbb{R}^{N}$ is the vector of noisy measurements.
#
# Derive the close form solution to this problem giving $z^\star$ as a function of $y$, $\gamma$ and $L$. Does this solution correspond to any graph filtering operation that you know?

# %% [markdown]
# ***To obtain the minimum, we use the first-order optimality condition,so we want the derivative of the formula evaluated to be equal to $0$.***
#
# ***Hence we first we have:***
#
# $$
# \text{arg} \, \underset{z \in \mathbb{R}^{N}}{\min} \, \frac{\tau}{2}\|z - y\|_2^2 + z^{\top} L z \implies
# Lz^\star + \frac{\tau}{2}(z^\star - y) = 0,
# $$
#
# ***where here we set $\tau = \frac{2}{\gamma}$.***
#
# ***Using the Graph Fourier Transform, we obtain:***
#
# $$
# \widehat{Lz^\star}({l}) + \frac{\tau}{2}(\widehat{z^\star}(l) - \widehat{y}(l)) = 0 \, \, \, \, \forall l \in \{0, 1, ..., N-1\}
# $$
#
# $$
# \implies \widehat{z^\star}(l) = \frac{\tau}{\tau + 2\lambda_{l}}\widehat{y}(l)
# $$
#
# $$
# \implies \widehat{z^\star}(l) = \frac{\frac{2}{\gamma}}{\frac{2}{\gamma} + 2\lambda_{l}}\widehat{y}(l)
# = \frac{1}{1 + 2\gamma\lambda_{l}}\widehat{y}(l)
# $$
#
# ***This solution corresponds to a Low pass filter.***

# %% [markdown]
# ### Question 11
#
# Now, denoise the noisy measurements by passing them through the filters that you implemented in Question 6. Choose the filter parameters based on the behavior of the GFT of your original label signal (this is the prior knowledge that you input to the problem).

# %%
z_heat_denoised = graph_filter(noisy_measurements, heat_kernel, e = e, t = 0.05)
z_inv_denoised = graph_filter(noisy_measurements, inverse_kernel, e = e, t = -0.1)
z_rect_denoised = graph_filter(noisy_measurements, rectangle_kernel, e = e, l_min = 0, l_max = 5)
# Out:
# Shape after GFT (3330,)
# Shape after kernel (3330,)
# Shape after GFT (3330,)
# Shape after kernel (3330, 1)
# Shape after GFT (3330,)
# Shape after kernel (3330,)

# %% [markdown]
# Plot, on your graph, the original label signal, the noisy measurements, and the three denoised version obtained above. Report on each plot the value of the corresponding relative error
# $$
# \text{rel-err} = \frac{\|\text{labels} - z \|_2}{\|\text{labels}\|_2},
# $$
# where $z$ is the plotted signal.

# %%
def rel_err(signal, measurements):
    return np.linalg.norm(signal - measurements) / np.linalg.norm(signal)

# %%
plt.figure(figsize=(20, 12))

plt.subplot(231)
plt.plot(e, labels, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, labels)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('Original label signal')
plt.legend()

plt.subplot(232)
plt.plot(e, noisy_measurements, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, noisy_measurements)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('Noisy measurements')
plt.legend()

plt.subplot(233)
plt.plot(e, z_heat_denoised, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, z_heat_denoised)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('Heat kernel as a function of the eigenvalues')
plt.legend()

plt.subplot(234)
plt.plot(e, z_inv_denoised, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, z_inv_denoised)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('Inverse kernel as a function of the eigenvalues')
plt.legend()

plt.subplot(235)
plt.plot(e, z_rect_denoised, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, z_rect_denoised)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('Rectangle kernel as a function of the eigenvalues')
plt.legend()

plt.show()

# %% [markdown]
# Finally, overlay on the same plot the GFT of all five signals above.

# %%
plt.figure(figsize=(10, 10))
plt.semilogy(e, GFT(labels), color = 'lightskyblue', label = 'labels')
plt.semilogy(e, GFT(noisy_measurements), color = 'orangered', label = 'noisy_measurements')
plt.semilogy(e, GFT(z_heat_denoised), color = 'springgreen', label = 'z_heat_denoised')
plt.semilogy(e, GFT(z_inv_denoised), color = 'orange', label = 'z_inv_denoised')
plt.semilogy(e, GFT(z_rect_denoised), color = 'palevioletred', label = 'z_rect_denoised')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.legend()

# %% [markdown]
# ### Question 12
#
# Comment on which denoised version seems to best match the original label signal. What is the underlying assumption behind the three filtering approaches? Do you think it holds for your label signal? Why?

# %% [markdown]
# ***By looking at the plot of the heat kernel, inverse kernel and rectangle kernel, we clearly see that the heat kernel produces the smallest relative error. By looking at the graph above, we can see that the GFT of the heat kernel is quiet similar in shape as the GFT of the original one, even if it has been shifted down.***

# %% [markdown]
# ## 4 - Transductive learning
#
# It is often the case in large networks that we can only afford to query properties/labels on a small subset of nodes. Nonetheless, if the underlying labels signal is "regular" enough, we might still be able to recover a good approximation of it by solving an offline variational problem, with constraints on the values of the measured nodes.
#
# In this section, we will be interested in solving such transductive learning problems by minimizing a (semi-) p-norm of the graph gradient applied to the signal of interest:
#
# $$
# \text{arg} \, \underset{z|_S = y}{\min} \|\nabla_G z\|_p^p,
# $$
#
# where $S$ is the set of measured nodes.
#
# In English, we can say that we are looking for solutions with small "aggregated local variations", as measured by $\|\nabla_G z\|_p^p = \sum_{i=1}^{n} \sum_{j=1}^{n} \left( \sqrt{W_{ij}} |z[i] - z[j]| \right)^p,$ while satisfying the measurement constraints $z[i] = y[i]$ for $i \in S.$
#
# We will work with two cases, according to the choices $p=1$ or $p=2.$ For $p=1,$ the problem is known as "interpolation by graph total-variation minimization," whereas for $p=2$ it is sometimes called "interpolation by Tikhonov regularization".
#
# In order to solve these variational problems with the black-box solver provided to you, you will use the [pyunlocbox](https://pyunlocbox.readthedocs.io). This toolbox implements iterative solvers based on so-called ["proximal-splitting"](https://en.wikipedia.org/wiki/Proximal_gradient_method) methods.

# %% [markdown]
# ### Question 13
#
# Throughout this section, we will consider only a binarized version of your label signal. If your variable `labels` currently has values other than $\{-1, 1\},$ threshold them so that those are the only values taken in this vector. This can be done for example by choosing a number $t \in \mathbb{R}$ and then setting $\text{labels_bin}[i] = 1$ if $\text{labels}[i] \geq t$ and $\text{labels_bin}[i] = 0$ otherwise.

# %%
def get_labels_bin(threshold):
    return [-1 if v <= threshold else 1 for v in labels]

# %%
labels_bin = get_labels_bin(2)

# %% [markdown]
# Now, subsample this binarized label signal by $70\%$ by choosing, uniformly at random, $30\%$ of the nodes whose labels we will keep.
#
# You will do this by computing a "measurement mask" vector `w` with `1.0`'s at the measured coordinates, and $0.0$'s otherwise.

# %%
def getMask(ratio):
    m = int(ratio * n_nodes)
    w = np.array([1]*m+[0]*(n_nodes-m))
    #np.random.seed(45687)
    np.random.shuffle(w)
    return w

# %%
w = getMask(ratio = 0.3)
Sub_ls = w * get_labels_bin(2)
Signal = np.asarray([ np.nan  if v == 0 else v for v in Sub_ls])

# %% [markdown]
# Plot the subsampled signal on the graph. _Hint:_ you might want to set to `numpy.nan` the values of the un-measured nodes for a cleaner plot.

# %%
plt.figure(figsize=(20, 5))

plt.plot(e, Signal)
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('Subsampled label signal')
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Interlude
#
# For the solution of the variational problems you can use the following function as a "black-box".
#
# You will just need to provide a `gradient` matrix (which you should already have from Section 0), and an orthogonal projection operator `P` onto the span of the measured coordinates (made precise in the next question).

# %%
def graph_pnorm_interpolation(gradient, P, x0=None, p=1., **kwargs):
    r"""
    Solve an interpolation problem via gradient p-norm minimization.

    A signal :math:`x` is estimated from its measurements :math:`y = A(x)` by solving
    :math:`\text{arg}\underset{z \in \mathbb{R}^n}{\min}
    \| \nabla_G z \|_p^p \text{ subject to } Az = y` 
    via a primal-dual, forward-backward-forward algorithm.

    Parameters
    ----------
    gradient : array_like
        A matrix representing the graph gradient operator
    P : callable
        Orthogonal projection operator mapping points in :math:`z \in \mathbb{R}^n` 
        onto the set satisfying :math:`A P(z) = A z`.
    x0 : array_like, optional
        Initial point of the iteration. Must be of dimension n.
        (Default is `numpy.random.randn(n)`)
    p : {1., 2.}
    kwargs :
        Additional solver parameters, such as maximum number of iterations
        (maxit), relative tolerance on the objective (rtol), and verbosity
        level (verbosity). See :func:`pyunlocbox.solvers.solve` for the full
        list of options.

    Returns
    -------
    x : array_like
        The solution to the optimization problem.

    """
    
    grad = lambda z: gradient.dot(z)
    div = lambda z: gradient.transpose().dot(z)

    # Indicator function of the set satisfying :math:`y = A(z)`
    f = functions.func()
    f._eval = lambda z: 0
    f._prox = lambda z, gamma: P(z)

    # :math:`\ell_1` norm of the dual variable :math:`d = \nabla_G z`
    g = functions.func()
    g._eval = lambda z: np.sum(np.abs(grad(z)))
    g._prox = lambda d, gamma: functions._soft_threshold(d, gamma)

    # :math:`\ell_2` norm of the gradient (for the smooth case)
    h = functions.norm_l2(A=grad, At=div)

    stepsize = (0.9 / (1. + scipy.sparse.linalg.norm(gradient, ord='fro'))) ** p

    solver = solvers.mlfbf(L=grad, Lt=div, step=stepsize)

    if p == 1.:
        problem = solvers.solve([f, g, functions.dummy()], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    if p == 2.:
        problem = solvers.solve([f, functions.dummy(), h], x0=x0, solver=solver, **kwargs)
        return problem['sol']
    else:
        return x0

# %% [markdown]
# ### Question 14
#
# During the iterations of the algorithm used for solving the variational problem, we have to make sure that the labels at the measured nodes stay the same. We will do this by means of an operator `P` which, given a vector $a \in \mathbb{R}^{N},$ returns another vector $b \in \mathbb{R}^{N}$ satisfying $b[i] = \text{labels_bin}[i]$ for every node $i$ in the set $S$ of known labels, and $b[i] = a[i]$ otherwise. Write in the cell below the function for this orthogonal projection operator `P`.
#
# _Hint:_ remember you have already computed the mask `w`.

# %%
def P(a):
    b = np.array([ labels_bin[i] if w[i] else a[i] for i in range(len(a))])
    return b

# %% [markdown]
# ### Question 15
#
# Solve the variational problems for $p = 1$ and $p = 2$. Record the solution for the $1-$norm minimization under `sol_1norm_min` and the one for $2-$norm minimization under `sol_2norm_min`.
#
# Compute also binarized versions of these solutions by thresholding the values with respect to $0$, that is, non-negative values become `1.0`, while negative values become `-1.0`. Store those binarized versions under `sol_1norm_bin` and `sol_2norm_bin`, respectively.

# %%
# ERROR . TODO 
sol_1norm_min = graph_pnorm_interpolation(gradient, P, x0=e ,p=1.)
# ERROR . TODO
sol_2norm_min = graph_pnorm_interpolation(gradient, P, x0=e, p=2.)

threshold = 0

sol_1norm_bin = np.sign(sol_1norm_min)

sol_2norm_bin = np.sign(sol_2norm_min)
# Out:
# Solution found after 45 iterations:
#     objective function f(sol) = 7.523828e+04
#     stopping criterion: RTOL
# Solution found after 200 iterations:
#     objective function f(sol) = 1.020076e+05
#     stopping criterion: MAXIT

# %% [markdown]
# Plot, on your graph, the original `labels_bin` signal, as well as the solutions to the variational problems (both binarized and otherwise). Indicate on each plot the value of the relative error $\text{rel-err} = \frac{\|\text{labels_bin} - z\|_2}{\|\text{labels_bin}\|_2}$, where $z$ is the signal in the corresponding plot.

# %%
plt.figure(figsize=(20, 12))

plt.subplot(231)
plt.plot(e, labels_bin)
#plt.plot(e, np.full((len(e),), rel_err(labels, labels)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('Original Label_bins signal')
plt.legend()

plt.subplot(232)
plt.plot(e, sol_1norm_min, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, sol_1norm_min)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('1-norm solution')
plt.legend()

plt.subplot(233)
plt.plot(e, sol_1norm_bin, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, sol_1norm_bin)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('1-norm solution binarized')
plt.legend()

plt.subplot(234)
plt.plot(e, sol_2norm_min, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, sol_2norm_min)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('2-norm solution')
plt.legend()

plt.subplot(235)
plt.plot(e, sol_2norm_bin, label = 'signal')
plt.plot(e, np.full((len(e),), rel_err(labels, sol_2norm_bin)), color = 'red', label = 'relative error')
plt.xlabel('Eigenvalues')
plt.ylabel('Value of the signal')
plt.title('2-norm solution binarized')
plt.legend()

plt.show()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# ### Question 16
#
# Now that you have got a feeling for the sort of solutions that the transductive learning problems studied can give, we will see what is the effect of the number of measurements on the accuracy of both $p-$norm minimization problems.
#
# Towards this goal, you will write a `phase_transition()` function. This function will basically go over all the procedures that you have implemented in this section, but for varying numbers of measurements and thresholding values. It will also compute the relative error, $\text{rel-err},$ of the solutions and average them over a number of trials.
#
# The output of the `phase_transition()` function has to be a matrix with `len(mn_ratios)` columns and `len(thresholds)` rows. Each pixel $(i,j)$ in the output matrix has to contain the average, over `n_trials` trials, of the relative error $\text{rel-err}$ in the binarized (with threshold `thresholds[i]`) solution given by `graph_pnorm_interpolation()` from observing an `mn_ratios[j]` fraction of nodes. The randomness comes from a different choice of mask `w` at each trial, hence the averaging.
#
# The interest of this phase transition matrix is to assess what level of recovery error one could expect for a certain fraction of measurements and a certain threshold level.

# %%
def phase_transition(mn_ratios, thresholds, n_trials, labels_bin, p):
    pt_matrix = np.zeros((len(thresholds),len(mn_ratios)))
    for ratio_index in range(len(mn_ratios)):
        for thresh_index in range(len(thresholds)):
            w = getMask(mn_ratios[ratio_index])
            labels_bins = get_labels_bin(thresholds[thresh_index])
            Sub_ls = w * labels_bins
            Signal = np.asarray([ np.nan  if v == 0 else v for v in Sub_ls])
            err_sum = 0
            for _iter in range(n_trials): 
                inter = graph_pnorm_interpolation(gradient, P, e, p)
                err_sum += rel_err(inter, Sub_ls)
            print(np.mean(err_sum))
            pt_matrix[thresh_index][ratio_index] = np.mean(err_sum)
    
    return pt_matrix

# %% [markdown]
# ### Question 17
#
# Pick 5 "m/n" ratios in $(0, 1)$ and 5 threshold levels in $(-1, 1)$ and run the `phase_transition()` function with `n_trials` = 20, for both $p = 1$ and $p = 2$.

# %%
mn_ratios = [0.2, 0.35, 0.5, 0.65, 0.8]

thresholds = [1,2,3]

pt_matrix_1norm = phase_transition(mn_ratios, thresholds, 20, None, 1)

pt_matrix_2norm = phase_transition(mn_ratios, thresholds, 20, None, 2)
# Out:
# Solution found after 37 iterations:
#     objective function f(sol) = 8.198806e+04
#     stopping criterion: RTOL
# Solution found after 16 iterations:
#     objective function f(sol) = 2.962378e+04
#     stopping criterion: RTOL
# Solution found after 35 iterations:
#     objective function f(sol) = 8.433466e+04
#     stopping criterion: RTOL
# Solution found after 45 iterations:
#     objective function f(sol) = 9.035098e+04
#     stopping criterion: RTOL
# Solution found after 46 iterations:
#     objective function f(sol) = 9.230782e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.253016e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.235935e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.244248e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.245654e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.237097e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.237581e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.228551e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.235062e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.225926e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.234664e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.224202e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.234681e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.225037e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.237204e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.225593e+04
#     stopping criterion: RTOL
# 20.10541522121542
# Solution found after 47 iterations:
#     objective function f(sol) = 9.237949e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.225548e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.238780e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.226057e+04
#     stopping criterion: RTOL
# Solution found after 47 iterations:
#     objective function f(sol) = 9.239958e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.217627e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.157972e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.139888e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.127956e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.113538e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.115316e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.102359e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.109603e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097300e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.107195e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094731e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.105976e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093420e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.105382e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.092593e+04
#     stopping criterion: RTOL
# 19.93404793628075
# Solution found after 48 iterations:
#     objective function f(sol) = 9.104958e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.092074e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.104670e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.091656e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.104407e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.091374e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.104219e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.091152e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.104057e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.090984e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.103916e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.090829e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.103772e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.090692e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.103641e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.090556e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.103517e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.090426e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.103397e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.090294e+04
#     stopping criterion: RTOL
# 20.03734154361774
# Solution found after 48 iterations:
#     objective function f(sol) = 9.103274e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.090171e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.103150e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.090047e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.103019e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.089923e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.102887e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.089800e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.102754e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.089682e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.102620e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.089566e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.102483e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.089448e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.102346e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.089327e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.102207e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.089205e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.102069e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.089080e+04
#     stopping criterion: RTOL
# 20.160800580856613
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101931e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088955e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101823e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088850e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101780e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088814e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101776e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088861e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101779e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088812e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101704e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088714e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101606e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088637e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101520e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088552e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101428e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088474e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101338e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088394e+04
#     stopping criterion: RTOL
# 19.90373502515525
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101246e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088314e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101155e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088233e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.101064e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088152e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100972e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.088071e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100881e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087990e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100790e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087908e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100699e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087826e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100608e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087744e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100516e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087662e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100425e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087580e+04
#     stopping criterion: RTOL
# 20.141391934249512
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100333e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087498e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100242e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087416e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100151e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087333e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.100059e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087251e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099968e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087168e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099876e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087086e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099784e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.087004e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099692e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086921e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099600e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086839e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099508e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086756e+04
#     stopping criterion: RTOL
# 20.507438179436477
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099417e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086673e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099325e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086591e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099233e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086508e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099142e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086424e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.099050e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086341e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098959e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086258e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098868e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086174e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098776e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086091e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098685e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.086007e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098594e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085923e+04
#     stopping criterion: RTOL
# 19.810049058414332
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098503e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085840e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098412e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085756e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098321e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085671e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098230e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085587e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098139e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085503e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.098048e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085418e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097958e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085334e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097867e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085249e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097776e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085164e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097686e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085080e+04
#     stopping criterion: RTOL
# 20.079818055185193
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097595e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084995e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097505e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084910e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097414e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084825e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097324e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084743e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097231e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084681e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.097123e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084644e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.096999e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084632e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.096857e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084643e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.096700e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084675e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.096529e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084724e+04
#     stopping criterion: RTOL
# 20.758417401146026
# Solution found after 48 iterations:
#     objective function f(sol) = 9.096349e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084782e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.096185e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084844e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.096020e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084906e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.095856e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084966e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.095693e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085020e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.095535e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085096e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.095377e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085172e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.095221e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085239e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.095071e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085299e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094926e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085353e+04
#     stopping criterion: RTOL
# 19.84906082253208
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094788e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085404e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094655e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085406e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094556e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085384e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094475e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085353e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094405e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085320e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094342e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085287e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094283e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085251e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094234e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085213e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094188e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085175e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094143e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085143e+04
#     stopping criterion: RTOL
# 20.340266653773824
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094099e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085110e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094054e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085077e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.094010e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085043e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093965e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.085009e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093921e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084974e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093877e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084939e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093834e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084903e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093800e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084867e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093766e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084830e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093731e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084793e+04
#     stopping criterion: RTOL
# 21.053914019436437
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093696e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084756e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093660e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084718e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093623e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084681e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093587e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084642e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093550e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084604e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093512e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084565e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093475e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084527e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093437e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084487e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093398e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084448e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093360e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084408e+04
#     stopping criterion: RTOL
# 19.90839307690418
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093321e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084368e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093281e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084328e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093242e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084287e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093203e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084246e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093164e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084206e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093125e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084166e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093085e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084126e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093046e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084086e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.093006e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084045e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.092965e+04
#     stopping criterion: RTOL
# Solution found after 48 iterations:
#     objective function f(sol) = 9.084005e+04
#     stopping criterion: RTOL
# 20.345807024376388
# Solution found after 200 iterations:
#     objective function f(sol) = 1.305329e+05
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 3.719007e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.726366e+04
#     stopping criterion: MAXIT
# Solution found after 200 iterations:
#     objective function f(sol) = 1.132349e+04
#     stopping criterion: MAXIT
# Solution found after 1 iterations:
#     objective function f(sol) = 1.132030e+04
#     stopping criterion: RTOL
# Solution found after 125 iterations:
#     objective function f(sol) = 9.694527e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.698610e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.689116e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.679556e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.670035e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.660553e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.651111e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.641709e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.632346e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.623022e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.613737e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.604491e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.595283e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.586114e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.576982e+03
#     stopping criterion: RTOL
# 20.981342268545653
# Solution found after 1 iterations:
#     objective function f(sol) = 9.567889e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.558833e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.549815e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.540835e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.531891e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.522985e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.514115e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.505282e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.496485e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.487725e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.479001e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.470312e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.461660e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.453043e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.444461e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.435914e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.427402e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.418926e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.410484e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.402076e+03
#     stopping criterion: RTOL
# 19.70045946492512
# Solution found after 1 iterations:
#     objective function f(sol) = 9.393702e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.385363e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.377058e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.368787e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.360549e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.352344e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.344173e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.336035e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.327931e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.319858e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.311819e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.303812e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.295837e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.287895e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.279984e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.272106e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.264259e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.256443e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.248659e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.240907e+03
#     stopping criterion: RTOL
# 20.54389377587256
# Solution found after 1 iterations:
#     objective function f(sol) = 9.233185e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.225494e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.217834e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.210205e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.202606e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.195037e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.187499e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.179991e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.172512e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.165063e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.157644e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.150255e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.142894e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.135563e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.128261e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.120988e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.113743e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.106527e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.099340e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.092181e+03
#     stopping criterion: RTOL
# 22.01710424437406
# Solution found after 1 iterations:
#     objective function f(sol) = 9.085050e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.077947e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.070872e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.063825e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.056805e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.049814e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.042849e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.035912e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.029002e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.022118e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.015262e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.008433e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 9.001630e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.994854e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.988104e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.981380e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.974682e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.968010e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.961365e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.954745e+03
#     stopping criterion: RTOL
# 19.733522630429345
# Solution found after 1 iterations:
#     objective function f(sol) = 8.948150e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.941581e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.935038e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.928520e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.922026e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.915558e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.909115e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.902697e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.896303e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.889934e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.883589e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.877269e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.870973e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.864701e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.858452e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.852228e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.846028e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.839851e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.833698e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.827568e+03
#     stopping criterion: RTOL
# 20.69800756112921
# Solution found after 1 iterations:
#     objective function f(sol) = 8.821461e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.815378e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.809318e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.803281e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.797267e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.791275e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.785306e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.779360e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.773436e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.767535e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.761656e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.755799e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.749964e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.744151e+03
# ...
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.621622e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.616287e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.610972e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.605676e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.600400e+03
#     stopping criterion: RTOL
# 19.910631959261455
# Solution found after 1 iterations:
#     objective function f(sol) = 8.595143e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.589906e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.584688e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.579489e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.574309e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.569148e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.564006e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.558883e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.553778e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.548692e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.543625e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.538576e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.533545e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.528533e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.523539e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.518563e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.513606e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.508666e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.503744e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.498840e+03
#     stopping criterion: RTOL
# 21.14280210718845
# Solution found after 1 iterations:
#     objective function f(sol) = 8.493954e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.489085e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.484234e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.479400e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.474584e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.469785e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.465004e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.460239e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.455492e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.450762e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.446049e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.441352e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.436673e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.432010e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.427364e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.422735e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.418122e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.413525e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.408945e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.404381e+03
#     stopping criterion: RTOL
# 23.228164891181027
# Solution found after 1 iterations:
#     objective function f(sol) = 8.399834e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.395302e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.390787e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.386288e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.381804e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.377337e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.372885e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.368449e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.364029e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.359625e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.355235e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.350862e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.346504e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.342161e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.337833e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.333521e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.329224e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.324942e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.320675e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.316423e+03
#     stopping criterion: RTOL
# 19.591287139921143
# Solution found after 1 iterations:
#     objective function f(sol) = 8.312185e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.307963e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.303755e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.299562e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.295384e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.291220e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.287071e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.282936e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.278815e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.274709e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.270617e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.266540e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.262476e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.258427e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.254391e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.250370e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.246362e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.242368e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.238388e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.234422e+03
#     stopping criterion: RTOL
# 20.891938056842058
# Solution found after 1 iterations:
#     objective function f(sol) = 8.230469e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.226530e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.222605e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.218693e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.214794e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.210909e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.207037e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.203178e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.199333e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.195501e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.191682e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.187875e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.184082e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.180302e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.176535e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.172780e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.169038e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.165309e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.161593e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.157889e+03
#     stopping criterion: RTOL
# 23.87307552656962
# Solution found after 1 iterations:
#     objective function f(sol) = 8.154198e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.150519e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.146853e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.143199e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.139557e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.135928e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.132311e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.128706e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.125114e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.121533e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.117964e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.114408e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.110863e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.107331e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.103810e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.100301e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.096803e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.093318e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.089844e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.086381e+03
#     stopping criterion: RTOL
# 19.484708999168245
# Solution found after 1 iterations:
#     objective function f(sol) = 8.082930e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.079491e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.076063e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.072646e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.069241e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.065847e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.062465e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.059094e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.055733e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.052384e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.049046e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.045719e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.042404e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.039099e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.035804e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.032521e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.029249e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.025987e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.022736e+03
#     stopping criterion: RTOL
# Solution found after 1 iterations:
#     objective function f(sol) = 8.019496e+03
#     stopping criterion: RTOL
# 21.395220050271416

# %% [markdown]
# Plot both phase transition matrices as images with a colorbar. Make sure to properly name the axes and title the images.

# %%
grid = pt_matrix_1norm
fig, ax = plt.subplots(figsize=(15, 7.5))
sns.heatmap(grid, ax = ax, square = True, annot = True, linewidth = 0.5, fmt='g')

# %%
grid = pt_matrix_2norm
fig, ax = plt.subplots(figsize=(15, 7.5))
sns.heatmap(grid, ax = ax, square = True, annot = True, linewidth = 0.5, fmt='g')

# %% [markdown]
# ### Question 18
#
# Do the phase transition plots above provide any justification for choosing one $p-$norm interpolation over the other? Why?

# %% [markdown]
# **Your answer here.**
